# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

import os
from glob import glob
from scipy.io import loadmat

import matplotlib.pyplot as plt
plt.style.use("seaborn-deep")
import seaborn as sns

from tensorflow import keras
from keras import Model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, GlobalAveragePooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import VGG16

import tensorflow as tf
import tensorflow_addons.losses.giou_loss as GIoU_Loss

from tqdm.auto import tqdm

from sklearn.metrics import classification_report, confusion_matrix

import cv2

import re

from skimage import io

from typing import Optional, Union, List, Tuple, ByteString, Dict

# %%
train_data = pd.read_csv('train.csv', dtype=str).dropna()
train_data.head()
# Out:
#                                     ruta_archivo   x1   y1   x2   y2 valencia  \
# 0    mscoco/images/COCO_val2014_000000562243.jpg   86   58  564  628        5
# 1  mscoco/images/COCO_train2014_000000288841.jpg  485  149  605  473        6
# 2    mscoco/images/COCO_val2014_000000558171.jpg  305   92  461  465        7
# 3  mscoco/images/COCO_train2014_000000369575.jpg  221   63  448  372        8
# 4  mscoco/images/COCO_train2014_000000213009.jpg   44  143  150  288        7
#
#   excitacion dominancia
# 0          3          9
# 1          4          7
# 2          8          8
# 3          9          8
# 4          9         10

# %%
val_data = pd.read_csv('val.csv', dtype=str).dropna()
val_data.head()
# Out:
#                                     ruta_archivo   x1   y1   x2   y2 valencia  \
# 0    mscoco/images/COCO_val2014_000000020459.jpg  109  108  401  450        4
# 1    mscoco/images/COCO_val2014_000000033835.jpg  404  222  563  473        6
# 2      emodb_small/images/arhnymaeequumexga8.jpg    2    2  370  266        5
# 3  mscoco/images/COCO_train2014_000000535817.jpg  149   89  425  351        6
# 4    mscoco/images/COCO_val2014_000000187857.jpg  291   32  489  349        6
#
#   excitacion dominancia
# 0          8          5
# 1          4          7
# 2          6          6
# 3          5          6
# 4          7          6

# %%
test_data = pd.read_csv('test.csv', dtype=str).dropna()
test_data.head()
# Out:
#                                     ruta_archivo   x1   y1   x2   y2 valencia  \
# 0     framesdb/images/frame_ghkq7yp0itqz0kn7.jpg  279   18  623  425        7
# 1  mscoco/images/COCO_train2014_000000537379.jpg  229  106  392  363        5
# 2  mscoco/images/COCO_train2014_000000049309.jpg  183  147  324  421        6
# 3  mscoco/images/COCO_train2014_000000353994.jpg  234   78  348  373        6
# 4  mscoco/images/COCO_train2014_000000336491.jpg  375   19  534  398        6
#
#   excitacion dominancia
# 0          4          6
# 1          6          7
# 2          7          7
# 3          9          7
# 4          6          5

# %%
def visualize_subplot(imgs: List[np.ndarray], titles: List[str], division: Tuple[int], figsize: Tuple[int] = None, cmap: str = "gray"):
    fig: plt.Figure = plt.figure(figsize=figsize)
    if figsize:
        fig.set_figwidth(figsize[0])
        fig.set_figheight(figsize[1])

    assert len(imgs) == len(titles), "La lista de imágenes y de títulos debe ser del mismo tamaño"
    assert np.prod(division) >= len(imgs)

    for index, title in enumerate(titles):
        ax: plt.Axes = fig.add_subplot(division[0], 
                            division[1], index+1)
        ax.imshow(imgs[index], cmap=cmap)
        ax.set_title(title)
        plt.axis("off")

# %%
np.random.seed(27)
random_sample = np.random.choice(train_data.shape[0], 9)
imgs = []
labels = []
for i in random_sample:
    img = io.imread(train_data.loc[i,"ruta_archivo"])
    imgs.append(img)
    labels.append("Val: " + str(train_data.loc[i,"valencia"]) +
                  " Exc: " + str(train_data.loc[i,"excitacion"]) +
                  " Dom: " + str(train_data.loc[i,"dominancia"]))

# %%
visualize_subplot(imgs, labels, (3, 3), (10, 10),)

# %%
train_list_ds_bbox = tf.data.Dataset.from_tensor_slices(train_data[['ruta_archivo','x1','y1','x2','y2']])
train_list_ds_bbox = train_list_ds_bbox.shuffle(len(train_list_ds_bbox), reshuffle_each_iteration=False)

train_list_ds_reg = tf.data.Dataset.from_tensor_slices(train_data[['ruta_archivo','valencia','excitacion','dominancia']])
train_list_ds_reg = train_list_ds_reg.shuffle(len(train_list_ds_reg), reshuffle_each_iteration=False)

# %%
val_list_ds_bbox = tf.data.Dataset.from_tensor_slices(val_data[['ruta_archivo','x1','y1','x2','y2']])
val_list_ds_bbox = val_list_ds_bbox.shuffle(len(val_list_ds_bbox), reshuffle_each_iteration=False)

val_list_ds_reg = tf.data.Dataset.from_tensor_slices(val_data[['ruta_archivo','valencia','excitacion','dominancia']])
val_list_ds_reg = val_list_ds_reg.shuffle(len(val_list_ds_reg), reshuffle_each_iteration=False)

# %%
test_list_ds_bbox = tf.data.Dataset.from_tensor_slices(test_data[['ruta_archivo','x1','y1','x2','y2']])
test_list_ds_bbox = test_list_ds_bbox.shuffle(len(test_list_ds_bbox), reshuffle_each_iteration=False)

test_list_ds_reg = tf.data.Dataset.from_tensor_slices(test_data[['ruta_archivo','valencia','excitacion','dominancia']])
test_list_ds_reg = test_list_ds_reg.shuffle(len(test_list_ds_reg), reshuffle_each_iteration=False)

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_data[['ruta_archivo','x1','y1','x2','y2','valencia','excitacion','dominancia']])
train_list_ds = train_list_ds.shuffle(len(train_list_ds), reshuffle_each_iteration=False)

val_list_ds = tf.data.Dataset.from_tensor_slices(val_data[['ruta_archivo','x1','y1','x2','y2','valencia','excitacion','dominancia']])
val_list_ds = train_list_ds.shuffle(len(val_list_ds), reshuffle_each_iteration=False)

test_list_ds = tf.data.Dataset.from_tensor_slices(test_data[['ruta_archivo','x1','y1','x2','y2','valencia','excitacion','dominancia']])
test_list_ds = train_list_ds.shuffle(len(test_list_ds), reshuffle_each_iteration=False)

# %%
BATCH_SIZE = 64
TRAIN_SIZE = len(train_list_ds_bbox)
VAL_SIZE = len(val_list_ds_bbox)
TEST_SIZE = len(test_list_ds_bbox)
SIZE = (200, 200)

# %%
@tf.function
def parse_ds_bbox_function(example_input: Optional[tf.Tensor],) -> Optional[Tuple[tf.Tensor]]:
    image = tf.io.read_file(example_input[0])
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32) / 255.

    x1 = tf.strings.to_number(example_input[1])
    y1 = tf.strings.to_number(example_input[2])
    x2 = tf.strings.to_number(example_input[3])
    y2 = tf.strings.to_number(example_input[4])

    return image, {'x1': x1, 'y1': y1, 'x2': x2, 'y2': y2}

@tf.function
def process_bbox(image: Optional[tf.Tensor], output: Optional[Dict[str,tf.Tensor]],) -> Optional[Tuple[tf.Tensor]]:
    shape = tf.shape(image)    
    image = tf.image.resize(image, SIZE)
    x_scale = 200. / tf.cast(shape[1], tf.float32)
    y_scale = 200. / tf.cast(shape[0], tf.float32)

    bbox = [tf.round(output['y1'] * y_scale),
            tf.round(output['x1'] * x_scale),
            tf.round(output['y2'] * y_scale),
            tf.round(output['x2'] * x_scale),]

    return image, bbox

# %%
train_ds_bbox = train_list_ds_bbox.map(parse_ds_bbox_function)
train_ds_bbox = train_ds_bbox.map(process_bbox)

val_ds_bbox = val_list_ds_bbox.map(parse_ds_bbox_function)
val_ds_bbox = val_ds_bbox.map(process_bbox)

test_ds_bbox = test_list_ds_bbox.map(parse_ds_bbox_function)
test_ds_bbox = test_ds_bbox.map(process_bbox)

# %%
imgs = []
for img, bbox in train_ds_bbox.take(4):
    new_img = cv2.rectangle(img.numpy(), (int(bbox[1]), int(bbox[0])), (int(bbox[3]), int(bbox[2])), (1, 0, 0), 3)
    imgs.append(new_img)

# %%
visualize_subplot(imgs, ["" for _ in imgs], (2, 2), (10, 10),)

# %%
@tf.function
def parse_ds_reg_function(example_input: Optional[tf.Tensor],) -> Optional[Tuple[tf.Tensor]]:
    image = tf.io.read_file(example_input[0])
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, SIZE)
    image = tf.cast(image, tf.float32) / 255.
    
    val = tf.strings.to_number(example_input[1])
    exc = tf.strings.to_number(example_input[2])
    dom = tf.strings.to_number(example_input[3])

    return image, [val, exc, dom]

# %%
train_ds_reg = train_list_ds_reg.map(parse_ds_reg_function)
val_ds_reg = val_list_ds_reg.map(parse_ds_reg_function)
test_ds_reg = test_list_ds_reg.map(parse_ds_reg_function)

# %%
@tf.function
def parse_ds_function(example_input: Optional[tf.Tensor],) -> Optional[Tuple[tf.Tensor]]:
    image = tf.io.read_file(example_input[0])
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32) / 255.
    
    x1 = tf.strings.to_number(example_input[1])
    y1 = tf.strings.to_number(example_input[2])
    x2 = tf.strings.to_number(example_input[3])
    y2 = tf.strings.to_number(example_input[4])
    
    shape = tf.shape(image)    
    image = tf.image.resize(image, SIZE)
    x_scale = 200. / tf.cast(shape[1], tf.float32)
    y_scale = 200. / tf.cast(shape[0], tf.float32)

    bbox = [tf.round(y1 * y_scale),
            tf.round(x1 * x_scale),
            tf.round(y2 * y_scale),
            tf.round(x2 * x_scale),]
    
    val = tf.strings.to_number(example_input[5])
    exc = tf.strings.to_number(example_input[6])
    dom = tf.strings.to_number(example_input[7])

    return image, bbox, [val, exc, dom]

# %%
train_ds = train_list_ds.map(parse_ds_function)
val_ds = val_list_ds.map(parse_ds_function)
test_ds = test_list_ds.map(parse_ds_function)

# %%
def performance(dataset: Optional[tf.data.Dataset], train: bool = True,) -> Optional[tf.data.Dataset]:
    if train:
        dataset = dataset.shuffle(512, reshuffle_each_iteration=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE)
    return dataset

# %%
train_ds_bbox = performance(train_ds_bbox)
train_ds_reg  = performance(train_ds_reg)

val_ds_bbox = performance(val_ds_bbox, False)
val_ds_reg = performance(val_ds_reg, False)

test_ds_bbox = performance(test_ds_bbox, False)
test_ds_reg = performance(test_ds_reg, False)

# %%
train_ds = performance(train_ds)
val_ds = performance(val_ds, False)
test_ds = performance(test_ds, False)

# %%
vgg = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(*SIZE, 3)))
vgg.trainable = False

flatten_bbox = Flatten()(vgg.output)
dense_1_bbox = Dense(128, activation = 'relu')(flatten_bbox)
dense_2_bbox = Dense(32, activation = 'relu')(dense_1_bbox)
output_bbox = Dense(4, activation = lambda x: 200*tf.keras.activations.sigmoid(x))(dense_2_bbox)
model_bbox_base = Model(inputs = vgg.inputs, outputs = output_bbox)
model_bbox_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 200, 200, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 200, 200, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 100, 100, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 100, 100, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 100, 100, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 50, 50, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 50, 50, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 50, 50, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 50, 50, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 25, 25, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 25, 25, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 12, 12, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  flatten_4 (Flatten)         (None, 18432)             0
#
#  dense_7 (Dense)             (None, 128)               2359424
#
#  dense_8 (Dense)             (None, 32)                4128
#
#  dense_9 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 17,078,372
# Trainable params: 2,363,684
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='min', baseline=None, restore_best_weights=False)
callbacks = [early_stopping]

# %%
model_bbox_base.compile(optimizer = keras.optimizers.Adam(learning_rate=0.0001), 
                 loss = GIoU_Loss)

# %%
params = {
    "steps_per_epoch": TRAIN_SIZE // BATCH_SIZE,
    "validation_steps": VAL_SIZE // BATCH_SIZE,
    "epochs": 250,
    "validation_data": val_ds_bbox,
    "verbose": 1,
    "callbacks": callbacks
}
history = model_bbox_base.fit(train_ds_bbox, **params)
# Out:
# Epoch 1/250
# 195/195 [==============================] - 2240s 11s/step - loss: 1.0015 - val_loss: 1.0000
# Epoch 2/250
# 195/195 [==============================] - 2245s 12s/step - loss: 1.0000 - val_loss: 1.0000
# Epoch 3/250
# 195/195 [==============================] - 2233s 11s/step - loss: 1.0000 - val_loss: 1.0000
# Epoch 4/250
# 195/195 [==============================] - 2230s 11s/step - loss: 1.0000 - val_loss: 1.0000
# Epoch 5/250
# 195/195 [==============================] - 2236s 11s/step - loss: 1.0000 - val_loss: 1.0000
# Epoch 00005: early stopping

# %%
for X_batch, y_batch in val_ds_bbox.take(1):
    break
np.random.seed(2)
random_sample = np.random.choice(len(X_batch), 9)
X_img = X_batch.numpy()[random_sample]
y_bboxs = y_batch.numpy()[random_sample]
y_bboxs_pred = model_bbox_base.predict(X_img)

# %%
imgs = []
labels = []
for img, bbox, pred_bbox in zip(X_img, y_bboxs, y_bboxs_pred):
    new_img = cv2.rectangle(img, (int(bbox[1]), int(bbox[0])), (int(bbox[3]), int(bbox[2])), (1, 0, 0), 3)
    new_img = cv2.rectangle(new_img, (int(pred_bbox[1]), int(pred_bbox[0])), (int(pred_bbox[3]), int(pred_bbox[2])), (0, 0, 1), 3)
    imgs.append(new_img)
    labels.append("")

# %%
visualize_subplot(imgs, labels, (3, 3), (10, 10),)

# %%
model_bbox_base.save('./modelo_bbox_giou.h5')

# %%
model_bbox_base.compile(optimizer = keras.optimizers.Adam(learning_rate=0.0001), loss = 'mse')

# %%
params = {
    "steps_per_epoch": TRAIN_SIZE // BATCH_SIZE,
    "validation_steps": VAL_SIZE // BATCH_SIZE,
    "epochs": 50,
    "validation_data": val_ds_bbox,
    "verbose": 1,
    "callbacks": callbacks
}
history = model_bbox_base.fit(train_ds_bbox, **params)
# Out:
# Epoch 1/50
# 195/195 [==============================] - 2236s 11s/step - loss: 457.2716 - val_loss: 416.0898
# Epoch 2/50
# 195/195 [==============================] - 2250s 12s/step - loss: 420.2852 - val_loss: 392.0949
# Epoch 3/50
# 195/195 [==============================] - 2236s 11s/step - loss: 391.3178 - val_loss: 356.8856
# Epoch 4/50
# 195/195 [==============================] - 2239s 12s/step - loss: 360.8013 - val_loss: 323.9194
# Epoch 5/50
# 195/195 [==============================] - 2233s 11s/step - loss: 334.7567 - val_loss: 297.7755
# Epoch 6/50
# 195/195 [==============================] - 2236s 11s/step - loss: 303.4906 - val_loss: 274.0227
# Epoch 7/50
# 195/195 [==============================] - 2257s 12s/step - loss: 275.7411 - val_loss: 254.5435
# Epoch 8/50
# 195/195 [==============================] - 2319s 12s/step - loss: 254.6010 - val_loss: 236.4429
# Epoch 9/50
# 195/195 [==============================] - 2295s 12s/step - loss: 230.6547 - val_loss: 217.5581
# Epoch 10/50
# 195/195 [==============================] - 2237s 12s/step - loss: 211.4681 - val_loss: 199.4433
# Epoch 11/50
# 195/195 [==============================] - 2247s 12s/step - loss: 193.8258 - val_loss: 192.3409
# Epoch 12/50
# 195/195 [==============================] - 2251s 12s/step - loss: 181.7607 - val_loss: 174.2980
# Epoch 13/50
# 195/195 [==============================] - 2242s 12s/step - loss: 164.8530 - val_loss: 162.3430
# Epoch 14/50
# 195/195 [==============================] - 2244s 12s/step - loss: 152.0002 - val_loss: 149.5498
# Epoch 15/50
# 195/195 [==============================] - 2254s 12s/step - loss: 138.4030 - val_loss: 139.7377
# Epoch 16/50
# 195/195 [==============================] - 2260s 12s/step - loss: 130.4921 - val_loss: 145.3056
# Epoch 17/50
# 195/195 [==============================] - 2257s 12s/step - loss: 118.5408 - val_loss: 134.0799
# Epoch 18/50
# 195/195 [==============================] - 2261s 12s/step - loss: 110.1450 - val_loss: 122.1171
# Epoch 19/50
# 195/195 [==============================] - 2261s 12s/step - loss: 100.5281 - val_loss: 108.4328
# Epoch 20/50
# 195/195 [==============================] - 2260s 12s/step - loss: 93.1777 - val_loss: 102.7411
# Epoch 21/50
# 195/195 [==============================] - 2260s 12s/step - loss: 86.7564 - val_loss: 104.1778
# Epoch 22/50
# 195/195 [==============================] - 2276s 12s/step - loss: 79.9541 - val_loss: 88.4074
# Epoch 23/50
# 195/195 [==============================] - 2283s 12s/step - loss: 75.2703 - val_loss: 91.0413
# Epoch 24/50
# 195/195 [==============================] - 2277s 12s/step - loss: 70.1207 - val_loss: 81.4254
# Epoch 25/50
# 195/195 [==============================] - 2267s 12s/step - loss: 66.7639 - val_loss: 76.0732
# Epoch 26/50
# 195/195 [==============================] - 2272s 12s/step - loss: 62.3189 - val_loss: 73.5392
# Epoch 27/50
# 195/195 [==============================] - 2277s 12s/step - loss: 56.1351 - val_loss: 69.9818
# Epoch 28/50
# 195/195 [==============================] - 2297s 12s/step - loss: 54.1497 - val_loss: 67.3748
# Epoch 29/50
# 195/195 [==============================] - 2278s 12s/step - loss: 51.4609 - val_loss: 63.9830
# Epoch 30/50
# 195/195 [==============================] - 2289s 12s/step - loss: 50.2370 - val_loss: 65.7442
# Epoch 31/50
# 195/195 [==============================] - 2279s 12s/step - loss: 46.8521 - val_loss: 61.4171
# Epoch 32/50
# 195/195 [==============================] - 2278s 12s/step - loss: 42.3981 - val_loss: 57.6868
# Epoch 33/50
# 195/195 [==============================] - 2289s 12s/step - loss: 40.8933 - val_loss: 55.6264
# Epoch 34/50
# 195/195 [==============================] - 2285s 12s/step - loss: 38.2906 - val_loss: 52.9371
# Epoch 35/50
# 195/195 [==============================] - 2284s 12s/step - loss: 37.6373 - val_loss: 49.1373
# Epoch 36/50
# 195/195 [==============================] - 2303s 12s/step - loss: 37.1622 - val_loss: 57.0276
# Epoch 37/50
# 195/195 [==============================] - 2280s 12s/step - loss: 34.2334 - val_loss: 52.8025
# Epoch 38/50
# 195/195 [==============================] - 2273s 12s/step - loss: 32.8492 - val_loss: 45.5882
# Epoch 39/50
# 195/195 [==============================] - 2274s 12s/step - loss: 31.6896 - val_loss: 49.4965
# Epoch 40/50
# 195/195 [==============================] - 2269s 12s/step - loss: 31.6332 - val_loss: 44.0741
# Epoch 41/50
# 195/195 [==============================] - 2272s 12s/step - loss: 28.9481 - val_loss: 44.3200
# Epoch 42/50
# 195/195 [==============================] - 2277s 12s/step - loss: 26.9348 - val_loss: 38.7863
# Epoch 43/50
# 195/195 [==============================] - 2269s 12s/step - loss: 26.3422 - val_loss: 41.2300
# Epoch 44/50
# 195/195 [==============================] - 2283s 12s/step - loss: 25.6008 - val_loss: 43.0156
# Epoch 45/50
# 195/195 [==============================] - 2280s 12s/step - loss: 26.4059 - val_loss: 40.5225
# Epoch 46/50
# 195/195 [==============================] - 2281s 12s/step - loss: 25.3883 - val_loss: 37.3483
# Epoch 47/50
# 195/195 [==============================] - 2275s 12s/step - loss: 24.7926 - val_loss: 40.8751
# Epoch 48/50
# 195/195 [==============================] - 2279s 12s/step - loss: 23.0765 - val_loss: 35.7194
# Epoch 49/50
# 195/195 [==============================] - 2283s 12s/step - loss: 21.7464 - val_loss: 33.4641
# Epoch 50/50
# 195/195 [==============================] - 2298s 12s/step - loss: 21.8637 - val_loss: 34.4529

# %%
for X_batch, y_batch in val_ds_bbox.take(1):
    break
np.random.seed(1)
random_sample = np.random.choice(len(X_batch), 9)
X_img = X_batch.numpy()[random_sample]
y_bboxs = y_batch.numpy()[random_sample]
y_bboxs_pred = model_bbox_base.predict(X_img)

# %%
imgs = []
labels = []
for img, bbox, pred_bbox in zip(X_img, y_bboxs, y_bboxs_pred):
    new_img = cv2.rectangle(img, (int(bbox[1]), int(bbox[0])), (int(bbox[3]), int(bbox[2])), (1, 0, 0), 3)
    new_img = cv2.rectangle(new_img, (int(pred_bbox[1]), int(pred_bbox[0])), (int(pred_bbox[3]), int(pred_bbox[2])), (0, 0, 1), 3)
    imgs.append(new_img)
    labels.append("")

# %%
visualize_subplot(imgs, labels, (3, 3), (10, 10),)

# %%
model_bbox_base.save('./modelo_bbox_mse.h5')

# %%
model_bbox_base.save_weights('modelo_bbox_mse_weights', save_format='tf')

# %%
inception = keras.applications.InceptionV3(include_top=False, weights="imagenet", input_shape=(*SIZE, 3),)
inception.trainable = False

flatten_emo = Flatten()(inception.output)
dense_1_emo = Dense(128, activation = 'relu')(flatten_emo)
dense_2_emo = Dense(32, activation = 'relu')(dense_1_emo)
output_emo = Dense(3, activation = lambda x: 10*tf.keras.activations.sigmoid(x))(dense_2_emo)
model_reg_base = Model(inputs = inception.inputs, outputs = output_emo)

model_reg_base.summary()
# Out:
# Model: "model_35"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_36 (InputLayer)          [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d_294 (Conv2D)            (None, 99, 99, 32)   864         ['input_36[0][0]']
#
#  batch_normalization_282 (Batch  (None, 99, 99, 32)  96          ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 99, 99, 32)   0           ['batch_normalization_282[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 97, 97, 32)   9216        ['activation_282[0][0]']
#
#  batch_normalization_283 (Batch  (None, 97, 97, 32)  96          ['conv2d_295[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 97, 97, 32)   0           ['batch_normalization_283[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 97, 97, 64)   18432       ['activation_283[0][0]']
#
#  batch_normalization_284 (Batch  (None, 97, 97, 64)  192         ['conv2d_296[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 97, 97, 64)   0           ['batch_normalization_284[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 48, 48, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_297 (Conv2D)            (None, 48, 48, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_285 (Batch  (None, 48, 48, 80)  240         ['conv2d_297[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 48, 48, 80)   0           ['batch_normalization_285[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 46, 46, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 46, 46, 192)  576        ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 46, 46, 192)  0           ['batch_normalization_286[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 22, 22, 192)  0          ['activation_286[0][0]']
#  )
#
#  conv2d_302 (Conv2D)            (None, 22, 22, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_290 (Batch  (None, 22, 22, 64)  192         ['conv2d_302[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_290[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 22, 22, 48)   9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_290[0][0]']
#
#  batch_normalization_288 (Batch  (None, 22, 22, 48)  144         ['conv2d_300[0][0]']
#  Normalization)
#
#  batch_normalization_291 (Batch  (None, 22, 22, 96)  288         ['conv2d_303[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_288[0][0]']
#
#  activation_291 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_291[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 22, 22, 192)  0          ['max_pooling2d_13[0][0]']
#  ooling2D)
#
#  conv2d_299 (Conv2D)            (None, 22, 22, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  conv2d_301 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_288[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_291[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 22, 22, 32)   6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (Batch  (None, 22, 22, 64)  192         ['conv2d_299[0][0]']
#  Normalization)
#
#  batch_normalization_289 (Batch  (None, 22, 22, 64)  192         ['conv2d_301[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 22, 22, 96)  288         ['conv2d_304[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 22, 22, 32)  96          ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_287[0][0]']
#
#  activation_289 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_289[0][0]']
#
#  activation_292 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_292[0][0]']
#
#  activation_293 (Activation)    (None, 22, 22, 32)   0           ['batch_normalization_293[0][0]']
#
#  mixed0 (Concatenate)           (None, 22, 22, 256)  0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 22, 22, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_297 (Batch  (None, 22, 22, 64)  192         ['conv2d_309[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_297[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 22, 22, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_297[0][0]']
#
#  batch_normalization_295 (Batch  (None, 22, 22, 48)  144         ['conv2d_307[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 22, 22, 96)  288         ['conv2d_310[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_295[0][0]']
#
#  activation_298 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_298[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 22, 22, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_306 (Conv2D)            (None, 22, 22, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_295[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_298[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 22, 22, 64)   16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_294 (Batch  (None, 22, 22, 64)  192         ['conv2d_306[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 22, 22, 64)  192         ['conv2d_308[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 22, 22, 96)  288         ['conv2d_311[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 22, 22, 64)  192         ['conv2d_312[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_294[0][0]']
#
#  activation_296 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_296[0][0]']
#
#  activation_299 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_299[0][0]']
#
#  activation_300 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_300[0][0]']
#
#  mixed1 (Concatenate)           (None, 22, 22, 288)  0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_304 (Batch  (None, 22, 22, 64)  192         ['conv2d_316[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_304[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 22, 22, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_304[0][0]']
#
#  batch_normalization_302 (Batch  (None, 22, 22, 48)  144         ['conv2d_314[0][0]']
#  Normalization)
#
#  batch_normalization_305 (Batch  (None, 22, 22, 96)  288         ['conv2d_317[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_302[0][0]']
#
#  activation_305 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_305[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 22, 22, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_313 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_302[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_305[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 22, 22, 64)   18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_301 (Batch  (None, 22, 22, 64)  192         ['conv2d_313[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 22, 22, 64)  192         ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_306 (Batch  (None, 22, 22, 96)  288         ['conv2d_318[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 22, 22, 64)  192         ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_301[0][0]']
#
#  activation_303 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_303[0][0]']
#
#  activation_306 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_306[0][0]']
#
#  activation_307 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_307[0][0]']
#
#  mixed2 (Concatenate)           (None, 22, 22, 288)  0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_309 (Batch  (None, 22, 22, 64)  192         ['conv2d_321[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_309[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_309[0][0]']
#
#  batch_normalization_310 (Batch  (None, 22, 22, 96)  288         ['conv2d_322[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_310[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 10, 10, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_310[0][0]']
#
#  batch_normalization_308 (Batch  (None, 10, 10, 384)  1152       ['conv2d_320[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 10, 10, 96)  288         ['conv2d_323[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 10, 10, 384)  0           ['batch_normalization_308[0][0]']
#
#  activation_311 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_311[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 10, 10, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 10, 10, 768)  0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_14[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_316 (Batch  (None, 10, 10, 128)  384        ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_316[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_316[0][0]']
#
#  batch_normalization_317 (Batch  (None, 10, 10, 128)  384        ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_317[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_317[0][0]']
#
#  batch_normalization_313 (Batch  (None, 10, 10, 128)  384        ['conv2d_325[0][0]']
#  Normalization)
#
#  batch_normalization_318 (Batch  (None, 10, 10, 128)  384        ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_313[0][0]']
#
#  activation_318 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_318[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_313[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_318[0][0]']
#
#  batch_normalization_314 (Batch  (None, 10, 10, 128)  384        ['conv2d_326[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 10, 10, 128)  384        ['conv2d_331[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_314[0][0]']
#
#  activation_319 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_319[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 10, 10, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_324 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 10, 10, 192)  172032      ['activation_314[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 10, 10, 192)  172032      ['activation_319[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_312 (Batch  (None, 10, 10, 192)  576        ['conv2d_324[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 10, 10, 192)  576        ['conv2d_327[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 10, 10, 192)  576        ['conv2d_332[0][0]']
#  Normalization)
#
#  batch_normalization_321 (Batch  (None, 10, 10, 192)  576        ['conv2d_333[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_312[0][0]']
#
#  activation_315 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_315[0][0]']
#
#  activation_320 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_320[0][0]']
#
#  activation_321 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_321[0][0]']
#
#  mixed4 (Concatenate)           (None, 10, 10, 768)  0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_326 (Batch  (None, 10, 10, 160)  480        ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_326[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_326[0][0]']
#
#  batch_normalization_327 (Batch  (None, 10, 10, 160)  480        ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_327[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_327[0][0]']
#
#  batch_normalization_323 (Batch  (None, 10, 10, 160)  480        ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_328 (Batch  (None, 10, 10, 160)  480        ['conv2d_340[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_323[0][0]']
#
#  activation_328 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_328[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_323[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_328[0][0]']
#
#  batch_normalization_324 (Batch  (None, 10, 10, 160)  480        ['conv2d_336[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 10, 10, 160)  480        ['conv2d_341[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_324[0][0]']
#
#  activation_329 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_329[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 10, 10, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_334 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_324[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_329[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_322 (Batch  (None, 10, 10, 192)  576        ['conv2d_334[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 10, 10, 192)  576        ['conv2d_337[0][0]']
#  Normalization)
#
#  batch_normalization_330 (Batch  (None, 10, 10, 192)  576        ['conv2d_342[0][0]']
#  Normalization)
#
#  batch_normalization_331 (Batch  (None, 10, 10, 192)  576        ['conv2d_343[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_322[0][0]']
#
#  activation_325 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_325[0][0]']
#
#  activation_330 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_330[0][0]']
#
#  activation_331 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_331[0][0]']
#
#  mixed5 (Concatenate)           (None, 10, 10, 768)  0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_336 (Batch  (None, 10, 10, 160)  480        ['conv2d_348[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_336[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_336[0][0]']
#
#  batch_normalization_337 (Batch  (None, 10, 10, 160)  480        ['conv2d_349[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_337[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_337[0][0]']
#
#  batch_normalization_333 (Batch  (None, 10, 10, 160)  480        ['conv2d_345[0][0]']
#  Normalization)
#
#  batch_normalization_338 (Batch  (None, 10, 10, 160)  480        ['conv2d_350[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_333[0][0]']
#
#  activation_338 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_338[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_333[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_338[0][0]']
#
#  batch_normalization_334 (Batch  (None, 10, 10, 160)  480        ['conv2d_346[0][0]']
#  Normalization)
#
#  batch_normalization_339 (Batch  (None, 10, 10, 160)  480        ['conv2d_351[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_334[0][0]']
#
#  activation_339 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_339[0][0]']
#
#  average_pooling2d_32 (AverageP  (None, 10, 10, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_344 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_334[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_339[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_32[0][0]']
#
#  batch_normalization_332 (Batch  (None, 10, 10, 192)  576        ['conv2d_344[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 10, 10, 192)  576        ['conv2d_347[0][0]']
#  Normalization)
#
#  batch_normalization_340 (Batch  (None, 10, 10, 192)  576        ['conv2d_352[0][0]']
#  Normalization)
#
#  batch_normalization_341 (Batch  (None, 10, 10, 192)  576        ['conv2d_353[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_332[0][0]']
#
#  activation_335 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_335[0][0]']
#
#  activation_340 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_340[0][0]']
#
#  activation_341 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_341[0][0]']
#
#  mixed6 (Concatenate)           (None, 10, 10, 768)  0           ['activation_332[0][0]',
#                                                                   'activation_335[0][0]',
# ...
#
#  activation_362 (Activation)    (None, 4, 4, 448)    0           ['batch_normalization_362[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 4, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_362[0][0]']
#
#  batch_normalization_359 (Batch  (None, 4, 4, 384)   1152        ['conv2d_371[0][0]']
#  Normalization)
#
#  batch_normalization_363 (Batch  (None, 4, 4, 384)   1152        ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_359[0][0]']
#
#  activation_363 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_363[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_363[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_363[0][0]']
#
#  average_pooling2d_34 (AverageP  (None, 4, 4, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_370 (Conv2D)            (None, 4, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_360 (Batch  (None, 4, 4, 384)   1152        ['conv2d_372[0][0]']
#  Normalization)
#
#  batch_normalization_361 (Batch  (None, 4, 4, 384)   1152        ['conv2d_373[0][0]']
#  Normalization)
#
#  batch_normalization_364 (Batch  (None, 4, 4, 384)   1152        ['conv2d_376[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 4, 4, 384)   1152        ['conv2d_377[0][0]']
#  Normalization)
#
#  conv2d_378 (Conv2D)            (None, 4, 4, 192)    245760      ['average_pooling2d_34[0][0]']
#
#  batch_normalization_358 (Batch  (None, 4, 4, 320)   960         ['conv2d_370[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_360[0][0]']
#
#  activation_361 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_361[0][0]']
#
#  activation_364 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_364[0][0]']
#
#  activation_365 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_365[0][0]']
#
#  batch_normalization_366 (Batch  (None, 4, 4, 192)   576         ['conv2d_378[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 4, 4, 320)    0           ['batch_normalization_358[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 4, 768)    0           ['activation_360[0][0]',
#                                                                   'activation_361[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 4, 4, 768)    0           ['activation_364[0][0]',
#                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_366[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 4, 2048)   0           ['activation_358[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 4, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_371 (Batch  (None, 4, 4, 448)   1344        ['conv2d_383[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 4, 4, 448)    0           ['batch_normalization_371[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 4, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_384 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_371[0][0]']
#
#  batch_normalization_368 (Batch  (None, 4, 4, 384)   1152        ['conv2d_380[0][0]']
#  Normalization)
#
#  batch_normalization_372 (Batch  (None, 4, 4, 384)   1152        ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_368[0][0]']
#
#  activation_372 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_372[0][0]']
#
#  conv2d_381 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_372[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_372[0][0]']
#
#  average_pooling2d_35 (AverageP  (None, 4, 4, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_379 (Conv2D)            (None, 4, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_369 (Batch  (None, 4, 4, 384)   1152        ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_370 (Batch  (None, 4, 4, 384)   1152        ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_373 (Batch  (None, 4, 4, 384)   1152        ['conv2d_385[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 4, 4, 384)   1152        ['conv2d_386[0][0]']
#  Normalization)
#
#  conv2d_387 (Conv2D)            (None, 4, 4, 192)    393216      ['average_pooling2d_35[0][0]']
#
#  batch_normalization_367 (Batch  (None, 4, 4, 320)   960         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_369[0][0]']
#
#  activation_370 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_370[0][0]']
#
#  activation_373 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_373[0][0]']
#
#  activation_374 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_374[0][0]']
#
#  batch_normalization_375 (Batch  (None, 4, 4, 192)   576         ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 4, 4, 320)    0           ['batch_normalization_367[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_369[0][0]',
#                                                                   'activation_370[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 4, 4, 768)    0           ['activation_373[0][0]',
#                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_375[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_367[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'activation_375[0][0]']
#
#  flatten_39 (Flatten)           (None, 32768)        0           ['mixed10[0][0]']
#
#  dense_112 (Dense)              (None, 128)          4194432     ['flatten_39[0][0]']
#
#  dense_113 (Dense)              (None, 32)           4128        ['dense_112[0][0]']
#
#  dense_114 (Dense)              (None, 3)            99          ['dense_113[0][0]']
#
# ==================================================================================================
# Total params: 26,001,443
# Trainable params: 4,198,659
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
model_reg_base.compile(optimizer = keras.optimizers.Adam(learning_rate=0.0001), 
                 loss = 'mse')

# %%
params = {
    "steps_per_epoch": TRAIN_SIZE // BATCH_SIZE,
    "validation_steps": VAL_SIZE // BATCH_SIZE,
    "epochs": 50,
    "validation_data": val_ds_reg,
    "verbose": 1,
    "callbacks": callbacks
}
history = model_reg_base.fit(train_ds_reg, **params)
# Out:
# Epoch 1/50
# 195/195 [==============================] - 302s 2s/step - loss: 4.0791 - val_loss: 1.7025
# Epoch 2/50
# 195/195 [==============================] - 297s 2s/step - loss: 3.0234 - val_loss: 1.5888
# Epoch 3/50
# 195/195 [==============================] - 297s 2s/step - loss: 2.7504 - val_loss: 1.5736
# Epoch 4/50
# 195/195 [==============================] - 298s 2s/step - loss: 2.4982 - val_loss: 1.6252
# Epoch 5/50
# 195/195 [==============================] - 298s 2s/step - loss: 2.3406 - val_loss: 1.5536
# Epoch 6/50
# 195/195 [==============================] - 298s 2s/step - loss: 2.1825 - val_loss: 1.5145
# Epoch 7/50
# 195/195 [==============================] - 297s 2s/step - loss: 2.0612 - val_loss: 1.5321
# Epoch 8/50
# 195/195 [==============================] - 298s 2s/step - loss: 1.9315 - val_loss: 1.6471
# Epoch 9/50
# 195/195 [==============================] - 298s 2s/step - loss: 1.8101 - val_loss: 1.7404
# Epoch 00009: early stopping

# %%
model_reg_base.save_weights('modelo_reg_mse_weights', save_format='tf')

# %%
for X_batch, y_batch_bbox, y_batch_reg in train_ds.take(1):
    break
np.random.seed(7)
random_sample = np.random.choice(len(X_batch), 9)
X_img = X_batch.numpy()[random_sample]
y_reg = y_batch_reg.numpy()[random_sample]
y_reg_pred = model_reg_base.predict(X_img)
y_bboxs = y_batch_bbox.numpy()[random_sample]
y_bboxs_pred = model_bbox_base.predict(X_img)

# %%
imgs = []
labels = []
for img, reg, reg_pred, bbox, pred_bbox in zip(X_img, y_reg, y_reg_pred, y_bboxs, y_bboxs_pred):
    new_img = cv2.rectangle(img, (int(bbox[1]), int(bbox[0])), (int(bbox[3]), int(bbox[2])), (1, 0, 0), 3)
    new_img = cv2.rectangle(new_img, (int(pred_bbox[1]), int(pred_bbox[0])), (int(pred_bbox[3]), int(pred_bbox[2])), (0, 0, 1), 3)
    str_real = "Real: Val: " + str(round(reg[0])) + "; Exc: " + str(round(reg[1])) + "; Dom: " + str(round(reg[2]))
    str_pred = "\nPred: Val: " + str(round(pred_reg[0])) + "; Exc: " + str(round(pred_reg[1])) + "; Dom: " + str(round(pred_reg[2]))
    imgs.append(new_img)
    labels.append(str_real + str_pred)

# %%
visualize_subplot(imgs, labels, (3, 3), (15, 15),)

# %% [markdown]
# ## Saving bboxes images

# %%
for X_batch, y_batch in train_ds_reg.take(TRAIN_SIZE):
    for img, output in zip(X_batch, y_batch):
        print(output)
        break
    break
# Out:
# tf.Tensor([ 72.  69. 248.], shape=(3,), dtype=float32)

# %%
model_bbox_base.compile(optimizer = keras.optimizers.Adam(learning_rate=0.0001), loss = 'mse')

# %%
params = {
    "steps_per_epoch": TRAIN_SIZE // BATCH_SIZE,
    "validation_steps": VAL_SIZE // BATCH_SIZE,
    "epochs": 50,
    "validation_data": val_ds_reg_cut,
    "verbose": 1,
    "callbacks": callbacks
}
history = model_reg_base.fit(train_ds_reg_cut, **params)
# Out:
# Epoch 1/50
#  12/195 [>.............................] - ETA: 1:08:52 - loss: 158979.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-704ce877a367> in <module>
#       7     "callbacks": callbacks
#       8 }
# ----> 9 history = model_reg_base.fit(train_ds_reg_cut, **params)
#
# c:\program files\python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\program files\python37\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1267                 _r=1):
#    1268               callbacks.on_train_batch_begin(step)
# -> 1269               tmp_logs = self.train_function(iterator)
#    1270               if data_handler.should_sync:
#    1271                 context.async_wait()
#
# c:\program files\python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     904
#     905       with OptionalXlaContext(self._jit_compile):
# --> 906         result = self._call(*args, **kwds)
#     907
#     908       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     936       # In this case we have created variables on the first call, so we run the
#     937       # defunned version which is guaranteed to never create variables.
# --> 938       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     939     elif self._stateful_fn is not None:
#     940       # Release the lock early so that multiple threads can perform the call
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3041        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3042     return graph_function._call_flat(
# -> 3043         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3044
#    3045   @property
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1893       # No tape is watching; skip to running the function.
#    1894       return self._build_call_outputs(self._inference_function.call(
# -> 1895           ctx, args, cancellation_manager=cancellation_manager))
#    1896     forward_backward = self._select_forward_and_backward_functions(
#    1897         args,
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     536               inputs=args,
#     537               attrs=attrs,
# --> 538               ctx=ctx)
#     539         else:
#     540           outputs = execute.execute_with_cancellation(
#
# c:\program files\python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:
