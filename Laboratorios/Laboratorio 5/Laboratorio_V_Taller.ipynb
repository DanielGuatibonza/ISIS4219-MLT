# %% [markdown]
# <a href="https://colab.research.google.com/github/Camilojaravila/202120_ISIS4219_01-MACHINE_LEARNING_TECHNIQUES/blob/main/Lab_5/Taller/Laboratorio_V_Taller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://bloqueneon.uniandes.edu.co/content/enforced/52233-202120_ISIS4219_01/Laboratorios.png?_&d2lSessionVal=guLBE9l4cI9Tip6PM5JSzKgp6&_&d2lSessionVal=iDtWjzbHb92iC3sVmHUqajJ2k&_&d2lSessionVal=g2xptlvZ5GrV3W5yGlhIgeBnN" ><br>
# # Machine Learning Techniques - ISIS4219
#
# Segundo Semestre - 2021

# %% [markdown]
# ## Integrantes
#
# *   Integrante 1.
# *   Integrante 2.
# *   Integrante 3.

# %% [markdown]
# ## **Problema 1**
#
# - En la Universidad de Caltech, se creó un dataset de aves cuyos datos se encuentran en formato TFRecord y almacenan la etiqueta de la especie del ave junto con los datos de detección de la misma. El formato de detección del ave es la coordenada en X e Y de la esquina superior izquierda, el ancho y el largo del cuadro. Su deber es clasificar las 200 especies haciendo uso de redes neuronales convolucionales. Además, como punto extra, ud deberá clasificar y detectar al mismo tiempo a través de una red bimodal o de salida doble. Los datos se ven de la siguiente forma:
#
# ![image](https://docs.google.com/uc?export=download&id=1Qg9UTiKOEapYRyBt5nRjikZjs-RuNl_k)
#
# Pueden hacer uso del siguiente [recurso](https://colab.research.google.com/github/jpcano1/MINE_4210_Analisis_con_Deep_Learning/blob/master/extras/practica_tfrecord.ipynb) para guiarse.
#
# - [Data de entrenamiento](https://drive.google.com/file/d/1shoNNn7PuTB-Hv46RV1Hv8E4W4umDWII/view?usp=sharing)
# - [Data de Validación](https://drive.google.com/file/d/16MlEZxvNvuoek7IIDvs-JHxaKLE3OiZb/view?usp=sharing)
# - [Data de Testing](https://drive.google.com/file/d/1E0A0Ve4vBEyOZAw9f0f5f__uAgyvQvsa/view?usp=sharing)

# %%
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K

from skimage import io

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use("seaborn-deep")
import seaborn as sns

from sklearn.model_selection import ShuffleSplit
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix

from typing import Tuple, List, Union, Optional

# %%
train_ds = tf.data.TFRecordDataset(['./train.tfrec'])

# %%
for bla in train_ds.take(1):
    print(repr(bla))
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'\n\xec\x9c\x05\n\xc3\x9c\x05\n\x05image\x12\xb8\x9c\x05\n\xb4\x9c\x05\n\xb0\x9c\x05\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00\xf0\x00\xf0\x00\x00\xff\xe2\x02@ICC_PROFILE\x00\x01\x01\x00\x00\x020ADBE\x02\x10\x00\x00mntrRGB XYZ \x07\xcf\x00\x06\x00\x03\x00\x00\x00\x00\x00\x00acspAPPL\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-ADBE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ncprt\x00\x00\x00\xfc\x00\x00\x002desc\x00\x00\x010\x00\x00\x00kwtpt\x00\x00\x01\x9c\x00\x00\x00\x14bkpt\x00\x00\x01\xb0\x00\x00\x00\x14rTRC\x00\x00\x01\xc4\x00\x00\x00\x0egTRC\x00\x00\x01\xd4\x00\x00\x00\x0ebTRC\x00\x00\x01\xe4\x00\x00\x00\x0erXYZ\x00\x00\x01\xf4\x00\x00\x00\x14gXYZ\x00\x00\x02\x08\x00\x00\x00\x14bXYZ\x00\x00\x02\x1c\x00\x00\x00\x14text\x00\x00\x00\x00Copyright 1999 Adobe Systems Incorporated\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x11Adobe RGB (1998)XYZ \x00\x00\x00\x00\x00\x00\xf3Q\x00\x01\x00\x00\x00\x01\x16\xccXYZ \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00XYZ \x00\x00\x00\x00\x00\x00\x9c\x18\x00\x00O\xa5\x00\x00\x04\xfcXYZ \x00\x00\x00\x00\x00\x004\x8d\x00\x00\xa0,\x00\x00\x0f\x95XYZ \x00\x00\x00\x00\x00\x00&1\x00\x00\x10/\x00\x00\xbe\x9c\xff\xdb\x00C\x00\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x02\x02\x03\x02\x02\x02\x02\x02\x04\x03\x03\x02\x03\x05\x04\x05\x05\x05\x04\x04\x04\x05\x06\x07\x06\x05\x05\x07\x06\x04\x04\x06\t\x06\x07\x08\x08\x08\x08\x08\x05\x06\t\n\t\x08\n\x07\x08\x08\x08\xff\xdb\x00CM\x01\xf4\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x02\x02\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x06\x07\x05\x08\x03\x04\t\x02\n\x01\x00\x0b\xff\xc4\x00F\x10\x00\x01\x03\x02\x04\x04\x04\x03\x05\x07\x03\x04\x02\x00\x06\x03\x01\x02\x03\x04\x05\x11\x00\x06\x12!\x07\x131A\x08"Qa\x14q\xf02\x81\x91\xa1\xb1\t\x15#B\xc1\xd1\xe1\x16R\xf1\n$3b\x17r\x184CD\x82\x92Sc\xb2\xff\xc4\x00\x1e\x01\x00\x02\x03\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x03\x04\x01\x02\x05\x06\x00\x07\x08\t\n\xff\xc4\x00B\x11\x00\x01\x04\x01\x02\x04\x04\x03\x06\x05\x02\x05\x03\x04\x03\x00\x01\x00\x02\x03\x11\x04!1\x05\x12AQ\x06\x13"a\x14q\x81\x072\x91\xa1\xb1\xf0\x15B\xc1\xd1\xe1#R\x08\x163br\t\x92\xf1$4\x82\xb2\x83\xc2\xd2\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\x7fx\x9d}i\x8f=\xb4$t!$\x9b\x15o\xb1\x1e\x84\xef\x8f\x9cG\x8e\xee`\xbb\xe7\xba\x85\xae4g%\xbf\xf1\x92\n\x8a\x82\xca\xd4\x00(;\x8f\x9e\x1d\x18\xb5\xd1d\xc8\xf5Z3eM\xc83Kl\x156R7\x07\xd4o\xb6\x1a\x8a?H\xe6As\xadz\xc99\xa5\xe4\xccC\x05\xd5\x05\x8b\x10J\xad\xa7\xa5\xbb\xfb\xe1\xc6\xb2\x8d\xaa\xa7\xbcj\xda\xe42\x14T9\x80\x0f2M\xc9\xda\xff\x00\x8e,\xe6\xda\xb9z\x19\xab\xe7I\xf0\x99u\xb0\xa7.\xa3\xa1"\xfd~B\xfe\xc3\x0b\xc9\x15\xe8\xa8\x80)\xd5\x89\x95\x979r]\xb2u\x13{\xfeG\xf1\xc2RD\x01\xd1y>\xf2U9/\xad)!\t\x90\x05\xc1 \xf9\xbd\xc7\xf6\xc0_\xbab\x04\xdb\xabQV\xa8m!\xe4\x15$\xdb\xafT\xed\xd7\xe5\x80\x86j\x99s\t\x16\xa5r\xd9~\x1a\x1di\xb0\xda\x93\xb9\xb5\xb7\xbf\xe3kX\xe2\xb2\rP\\\xca^*\x19\xaaD\'\x9ca\xd5-)(\xb8+\xde\xc7\xd7\x ...
